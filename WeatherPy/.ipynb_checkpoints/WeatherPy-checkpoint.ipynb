# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 646

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units={units}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Make the API request
        response = requests.get(city_url)
    
        # Parse the JSON and retrieve data
        city_weather = response.json()


        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikhil
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | nar'yan-mar
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | udachny
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | enewetak
# Processing Record 9 of Set 1 | ingeniero guillermo n. juarez
# Processing Record 10 of Set 1 | waitangi
# Processing Record 11 of Set 1 | iqaluit
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | fort mcmurray
# Processing Record 14 of Set 1 | al mayadin
# Processing Record 15 of Set 1 | blackmans bay
# Processing Record 16 of Set 1 | mukah
# City not found. Skipping...
# Processing Record 17 of Set 1 | kapuskasing
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | poplar bluff
# Processing Record 20 of Set 1 | port-aux-francais
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          613
# Lat           613
# Lng           613
# Max Temp      613
# Humidity      613
# Cloudiness    613
# Wind Speed    613
# Country       613
# Date          613
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       dikhil  11.5000   42.1667     22.70        57          13        2.20
# 1       bethel  41.3712  -73.4140      3.67        68          40        1.43
# 2  nar'yan-mar  67.6713   53.0870     -2.11        88         100        7.31
# 3  new norfolk -42.7826  147.0587     19.28        40          35        4.78
# 4      udachny  66.4167  112.4000    -20.27        96          80        2.99
#
#   Country        Date
# 0      DJ  1730693632
# 1      US  1730693253
# 2      RU  1730693634
# 3      AU  1730693278
# 4      RU  1730693424

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             dikhil  11.5000   42.1667     22.70        57          13
# 1             bethel  41.3712  -73.4140      3.67        68          40
# 2        nar'yan-mar  67.6713   53.0870     -2.11        88         100
# 3        new norfolk -42.7826  147.0587     19.28        40          35
# 4            udachny  66.4167  112.4000    -20.27        96          80
#
#          Wind Speed Country        Date
# City_ID
# 0              2.20      DJ  1730693632
# 1              1.43      US  1730693253
# 2              7.31      RU  1730693634
# 3              4.78      AU  1730693278
# 4              2.99      RU  1730693424

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values, y_values, edgecolor="black")

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title("City Latitude vs. Max Temperature (2024-06-17)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values, y_values, edgecolor="black")

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("City Latitude vs. Humidity (2024-06-17)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values, y_values, edgecolor="black")


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("City Latitude vs. Cloudiness (2024-06-17)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values, y_values, edgecolor="black")

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title("City Latitude vs. Wind Speed (2024-06-17)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, save_path):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Get regression values
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             dikhil  11.5000   42.1667     22.70        57          13
# 1             bethel  41.3712  -73.4140      3.67        68          40
# 2        nar'yan-mar  67.6713   53.0870     -2.11        88         100
# 4            udachny  66.4167  112.4000    -20.27        96          80
# 5        yellowknife  62.4560 -114.3525     -1.99        99         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.20      DJ  1730693632
# 1              1.43      US  1730693253
# 2              7.31      RU  1730693634
# 4              2.99      RU  1730693424
# 5              1.54      CA  1730693240

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                   City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 3                          new norfolk -42.7826  147.0587     19.28        40
# 6                       port elizabeth -33.9180   25.5701     14.62        96
# 8        ingeniero guillermo n. juarez -23.9000  -61.8500     23.67        76
# 9                             waitangi -43.9535 -176.5597     10.46        69
# 11                              avarua -21.2078 -159.7750     25.03        88
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 3                35        4.78      AU  1730693278
# 6               100        4.02      ZA  1730693281
# 8                 0        1.72      AR  1730693641
# 9                70        2.24      NZ  1730693176
# 11              100        6.17      CK  1730693292

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line_eq, (2, -15), fontsize=15, color="red")
plt.title("Latitude vs Max Temp")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r^2-value is: 0.7622785086337014

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line_eq, (-56, 35), fontsize=15, color="red")
plt.title("Latitude vs Max Temp")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r^2-value is: 0.4401425149303941

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Discussion about the Linear Relationship:
#
# **Northern Hemisphere:**
# The linear regression for the Northern Hemisphere shows a negative slope of **-0.56**, indicating an inverse relationship between latitude and maximum temperature. As latitude increases, the maximum temperature tends to decrease. This pattern is expected since higher latitudes (further from the equator) generally experience cooler temperatures. The r-squared value of **0.76** suggests a relatively strong correlation, meaning latitude is a significant factor affecting temperature in the Northern Hemisphere.
#
# **Southern Hemisphere:**
# In the Southern Hemisphere, the regression line has a positive slope of **0.32**, suggesting that as latitude increases (moving closer to the equator from higher latitudes in the Southern Hemisphere), the maximum temperature also increases. This positive trend aligns with climatic expectations, as regions closer to the equator typically experience warmer temperatures. However, the r-squared value of **0.44** indicates a moderate correlation, suggesting that while latitude does influence temperature, other factors may also play a significant role in temperature variation in the Southern Hemisphere.
#
# **Overall Conclusion:**
# The analyses indicate that latitude has a notable impact on temperature, though the strength of this relationship differs between hemispheres. The Northern Hemisphere exhibits a stronger correlation between latitude and temperature, while the Southern Hemisphere shows a moderate correlation. Other environmental factors beyond latitude likely contribute to temperature variations, particularly in the Southern Hemisphere. These findings highlight the complex interactions between geographic location and climate.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq, (45, 15), fontsize=15, color="red")
plt.title("Latitude vs Humidity")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r^2-value is: 0.022892231021191003

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq, (-55, 18), fontsize=15, color="red")
plt.title("Latitude vs Humidity")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r^2-value is: 0.03524357691845247

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Discussion about the Linear Relationship:
#
# **Northern Hemisphere:**
#
# In the Northern Hemisphere, the linear regression shows a slight positive relationship between latitude and humidity. The equation of the line is \( y = 0.16x + 65.69 \), and the \( r^2 \)-value is approximately **0.0229**, indicating a very weak correlation. This low \( r^2 \)-value suggests that latitude is not a strong predictor of humidity in the Northern Hemisphere, and the majority of the variance in humidity is likely due to other factors.
#
# **Southern Hemisphere:**
#
# In the Southern Hemisphere, the linear regression also shows a slight positive relationship between latitude and humidity. The equation of the line is \( y = 0.26x + 78.45 \), with an \( r^2 \)-value of around **0.0352**. Similar to the Northern Hemisphere, this low \( r^2 \)-value indicates a very weak correlation between latitude and humidity. This suggests that latitude alone is not a significant predictor of humidity in the Southern Hemisphere, and other environmental or geographic factors may have a greater influence.
#
# **Overall Conclusion:**
#
# Both hemispheres display a minimal positive correlation between latitude and humidity, but the low \( r^2 \)-values highlight that latitude has little explanatory power for humidity levels in either hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq, (15, 60), fontsize=15, color="red")
plt.title("Latitude vs Cloudiness")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r^2-value is: 0.02268263663720246

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq, (-55, 40), fontsize=15, color="red")
plt.title("Latitude vs Cloudiness")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r^2-value is: 0.0010872000698511992

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Discussion about the Linear Relationship:
#
# **Northern Hemisphere:**
#
# In the Northern Hemisphere, the linear regression shows a slight positive relationship between latitude and cloudiness. The equation of the line is \( y = 0.3x + 44.1 \), and the \( r^2 \)-value is approximately **0.0227**, indicating a very weak correlation. This low \( r^2 \)-value suggests that latitude is not a strong predictor of cloudiness in the Northern Hemisphere, and the majority of the variance in cloudiness is likely due to other factors.
#
# **Southern Hemisphere:**
#
# In the Southern Hemisphere, the linear regression also shows a minimal positive relationship between latitude and cloudiness. The equation of the line is \( y = 0.09x + 64.85 \), with an \( r^2 \)-value of around **0.0011**. Similar to the Northern Hemisphere, this low \( r^2 \)-value indicates a very weak correlation between latitude and cloudiness. This suggests that latitude alone is not a significant predictor of cloudiness in the Southern Hemisphere, and other environmental or geographic factors may have a greater influence.
#
# **Overall Conclusion:**
#
# Both hemispheres display a minimal positive correlation between latitude and cloudiness, but the low \( r^2 \)-values highlight that latitude has little explanatory power for cloudiness levels in either hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq, (0, 13), fontsize=15, color="red")
plt.title("Latitude vs Wind Speed")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r^2-value is: 0.0691708721262422

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Label plot and annotate the line equation
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq, (-56, 0), fontsize=15, color="red")
plt.title("Latitude vs Wind Speed")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r^2-value is: 0.12846735454629638

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Discussion about the Linear Relationship:
#
# **Northern Hemisphere:**
#
# In the Northern Hemisphere, the linear regression shows a very slight positive relationship between latitude and wind speed. The equation of the line is \( y = 0.03x + 2.35 \), and the \( r^2 \)-value is approximately **0.069**. This low \( r^2 \)-value suggests that latitude is not a strong predictor of wind speed in the Northern Hemisphere. The variance in wind speed is likely influenced by other geographical or climatic factors.
#
# **Southern Hemisphere:**
#
# In the Southern Hemisphere, the linear regression shows a very slight negative relationship between latitude and wind speed. The equation of the line is \( y = -0.07x + 2.61 \), with an \( r^2 \)-value of around **0.128**. Similar to the Northern Hemisphere, this low \( r^2 \)-value indicates a weak correlation between latitude and wind speed, suggesting that latitude alone is not a significant predictor of wind speed in the Southern Hemisphere, and other factors may have a greater influence.
#
# **Overall Conclusion:**
#
# Both hemispheres display a minimal correlation between latitude and wind speed, as evidenced by the low \( r^2 \)-values. This indicates that latitude has little explanatory power for wind speed in either hemisphere, and other environmental or geographical factors likely contribute more significantly to wind speed variation.

# %% [markdown]
# **Overall Conclusion about Additional Influential Factors:**
#
# The weak correlation values observed in many of these analyses suggest that latitude alone is often not a strong predictor for variables like cloudiness, humidity, or wind speed. Other additional factors that may have a more significant influence include geographical features (such as proximity to mountains, oceans, or deserts), local climate zones, and seasonal variations. Additionally, atmospheric pressure systems, altitude, and prevailing wind patterns could also play crucial roles in shaping these weather-related variables. Therefore, for a more comprehensive understanding, it would be beneficial to consider these additional factors alongside latitude.
